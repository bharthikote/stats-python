# %%
data = [23,24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data.sort()

# %%
data
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
import seaborn as sns

# %%
sns.histplot(data, kde = True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
import pandas as pd

# %%
data2 = pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-TheCompleteGuide/main/Iris.csv")

# %%
data2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
import pandas as pd

# %%
sns.histplot(data2['SepalLengthCm'], kde = True)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.histplot(data2['SepalWidthCm'], kde = True)
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Count'>

# %%
import numpy as np

# %%
mean = np.mean(data2['SepalWidthCm'])
std_dev = np.std(data2['SepalWidthCm'])
std_dev
#mean
# Out:
# 0.4321465800705435

# %%
# Convert original data to standard normal data
standard_normal_data = (data2['SepalWidthCm'] - mean) / std_dev

print("Original Data:", data2['SepalWidthCm'])
print("Standard Normal Data:", standard_normal_data)
# Out:
# Original Data: 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SepalWidthCm, Length: 150, dtype: float64
# Standard Normal Data: 0      1.032057
# 1     -0.124958
# 2      0.337848
# 3      0.106445
# 4      1.263460
#          ...
# 145   -0.124958
# 146   -1.281972
# 147   -0.124958
# 148    0.800654
# 149   -0.124958
# Name: SepalWidthCm, Length: 150, dtype: float64

# %%
sns.histplot(standard_normal_data, kde = True)
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Count'>

# %%
data_copy = data.copy()
data_copy.append(289)
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 289]

# %%
sns.histplot(data_copy, kde = True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
data_copy2  = data.copy()

# %%
data_copy2[0] = -10
data_copy2[1] = -75
data_copy2
# Out:
# [-10, -75, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
sns.histplot(data_copy2, kde = True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
data2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.histplot(data2['PetalLengthCm'], kde = True)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Count'>

# %%
s = np.random.normal(0.5, 0.2, 1000)

# %%
sns.histplot(s, kde = True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
mu = 2.0
sigma = 0.6
p = np.random.lognormal(mu,sigma, 1000)

# %%
sns.histplot(p, kde = True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab
def plot_data(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample, kde= True)
    plt.subplot(1,2,2)
    stat.probplot(sample, dist= "norm", plot = pylab)
    plt.show()

# %%
from matplotlib import *

# %%
plot_data(data)

# %%
plot_data(data_copy)

# %%
plot_data(s)

# %%
plot_data(p)

# %%
plot_data(np.log(p))

# %%
pip install pandas-profiling
# Out:
# ...
#   Using cached pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
# ...
#      -------------------------------------- 357.3/357.3 kB 1.4 MB/s eta 0:00:00
# ...
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 9.4/9.4 MB 498.0 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.2/2.2 MB 442.6 kB/s eta 0:00:00
# ...
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# ...
#   Using cached visions-0.7.5-py3-none-any.whl (102 kB)
# ...
#   Using cached typeguard-2.13.3-py3-none-any.whl (17 kB)
# ...
#      ------------------------------------ 153.1/153.1 kB 835.5 kB/s eta 0:00:00
# ...
#   Using cached multimethod-1.9.1-py3-none-any.whl (10 kB)
# ...
#      ------------------------------------ 663.3/663.3 kB 759.4 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.2/4.2 MB 2.0 MB/s eta 0:00:00
# ...

# %%
import pandas_profiling
# Out:
# C:\conda_tmp\ipykernel_32568\1591302161.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling

# %%
profile = data2.profile_report()

# %%
profile.to_file(output_file = 'output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
